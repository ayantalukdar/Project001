# %%
import numpy as np
import pandas as pd

# %%
path=r"C:\Users\ayant\Desktop\Shared\Project001\Data\data_dictionary.csv"

# %%
df=pd.read_csv(path)
df
# Out:
#                   variable                                        description  \
# 0                dri_score                         Refined disease risk index
# 1            psych_disturb                            Psychiatric disturbance
# 2               cyto_score                                  Cytogenetic score
# 3                 diabetes                                           Diabetes
# 4         hla_match_c_high  Recipient / 1st donor allele level (high resol...
# 5           hla_high_res_8  Recipient / 1st donor allele-level (high resol...
# 6               tbi_status                                                TBI
# 7               arrhythmia                                         Arrhythmia
# 8            hla_low_res_6  Recipient / 1st donor antigen-level (low resol...
# 9               graft_type                                         Graft type
# 10               vent_hist                  History of mechanical ventilation
# ...

# %%
df.type.unique()
# Out:
# array(['Categorical', 'Numerical'], dtype=object)

# %%
df_cat=df[df['type']=="Categorical"]
df_num=df[df['type']=="Numerical"]

# %%
df_cat.reset_index(drop=True,inplace=True)
df_num.reset_index(drop=True,inplace=True)

# %%
df_cat
# Out:
#                   variable                                    description  \
# 0                dri_score                     Refined disease risk index
# 1            psych_disturb                        Psychiatric disturbance
# 2               cyto_score                              Cytogenetic score
# 3                 diabetes                                       Diabetes
# 4               tbi_status                                            TBI
# 5               arrhythmia                                     Arrhythmia
# 6               graft_type                                     Graft type
# 7                vent_hist              History of mechanical ventilation
# 8              renal_issue                       Renal, moderate / severe
# 9              pulm_severe                              Pulmonary, severe
# 10        prim_disease_hct                        Primary disease for HCT
# 11              cmv_status                 Donor/recipient CMV serostatus
# ...

# %%
df_num
# Out:
#                variable                                        description  \
# 0      hla_match_c_high  Recipient / 1st donor allele level (high resol...
# 1        hla_high_res_8  Recipient / 1st donor allele-level (high resol...
# 2         hla_low_res_6  Recipient / 1st donor antigen-level (low resol...
# 3        hla_high_res_6  Recipient / 1st donor allele-level (high resol...
# 4       hla_high_res_10  Recipient / 1st donor allele-level (high resol...
# 5   hla_match_dqb1_high  Recipient / 1st donor allele level (high resol...
# 6            hla_nmdp_6  Recipient / 1st donor matching at HLA-A(lo),-B...
# 7       hla_match_c_low  Recipient / 1st donor antigen level (low resol...
# 8    hla_match_drb1_low  Recipient / 1st donor antigen level (low resol...
# 9    hla_match_dqb1_low  Recipient / 1st donor antigen level (low resol...
# 10             year_hct                                        Year of HCT
# ...
