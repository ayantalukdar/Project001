# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
import missingno as msno
transaction_df = pd.read_csv("/home/avi/Code/CIBMR/Kaggle/Data/train.csv")

# %%
msno.bar(transaction_df,figsize=(60,30))
# Out:
# <Axes: >

# %%
msno.heatmap(transaction_df, cmap='YlGnBu',figsize=(60,30),vmin=-0.5,vmax=0.5)
# Out:
# <Axes: >

# %%
msno.dendrogram(transaction_df)
# Out:
# <Axes: >
